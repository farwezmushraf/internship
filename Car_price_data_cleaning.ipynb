# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression , Lasso , Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import TargetEncoder

# %%
data = pd.read_csv("/content/drive/MyDrive/Datasets/car_price_prediction.csv")

# %%
data.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  04-May        Left wheel   Black        8
# 2      Variator        Front  04-May  Right-hand drive   Black        2
# 3     Automatic          4x4  04-May        Left wheel   White        0
# 4     Automatic        Front  04-May        Left wheel  Silver        4

# %%
data.drop(columns= ["ID","Doors"],inplace=True)

# %%
data.head(3)
# Out:
#    Price  Levy Manufacturer    Model  Prod. year   Category Leather interior  \
# 0  13328  1399        LEXUS   RX 450        2010       Jeep              Yes
# 1  16621  1018    CHEVROLET  Equinox        2011       Jeep               No
# 2   8467     -        HONDA      FIT        2006  Hatchback               No
#
#   Fuel type Engine volume    Mileage  Cylinders Gear box type Drive wheels  \
# 0    Hybrid           3.5  186005 km        6.0     Automatic          4x4
# 1    Petrol             3  192000 km        6.0     Tiptronic          4x4
# 2    Petrol           1.3  200000 km        4.0      Variator        Front
#
#               Wheel   Color  Airbags
# 0        Left wheel  Silver       12
# 1        Left wheel   Black        8
# 2  Right-hand drive   Black        2

# %%
data.Levy  = data.Levy.replace("-",np.nan)

# %%
data.Levy = pd.to_numeric(data.Levy)
data.Levy = data.Levy.fillna(value=int(data.Levy.mean())).astype(int)

# %%
data.head()
# Out:
#    Price  Levy Manufacturer    Model  Prod. year   Category Leather interior  \
# 0  13328  1399        LEXUS   RX 450        2010       Jeep              Yes
# 1  16621  1018    CHEVROLET  Equinox        2011       Jeep               No
# 2   8467   906        HONDA      FIT        2006  Hatchback               No
# 3   3607   862         FORD   Escape        2011       Jeep              Yes
# 4  11726   446        HONDA      FIT        2014  Hatchback              Yes
#
#   Fuel type Engine volume    Mileage  Cylinders Gear box type Drive wheels  \
# 0    Hybrid           3.5  186005 km        6.0     Automatic          4x4
# 1    Petrol             3  192000 km        6.0     Tiptronic          4x4
# 2    Petrol           1.3  200000 km        4.0      Variator        Front
# 3    Hybrid           2.5  168966 km        4.0     Automatic          4x4
# 4    Petrol           1.3   91901 km        4.0     Automatic        Front
#
#               Wheel   Color  Airbags
# 0        Left wheel  Silver       12
# 1        Left wheel   Black        8
# 2  Right-hand drive   Black        2
# 3        Left wheel   White        0
# 4        Left wheel  Silver        4

# %%
data["Mileage"] = data["Mileage"].str.replace(" km", "")
data["Mileage"] = pd.to_numeric(data["Mileage"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             19237 non-null  int64
#  1   Levy              19237 non-null  int64
#  2   Manufacturer      19237 non-null  object
#  3   Model             19237 non-null  object
#  4   Prod. year        19237 non-null  int64
#  5   Category          19237 non-null  object
#  6   Leather interior  19237 non-null  object
#  7   Fuel type         19237 non-null  object
#  8   Engine volume     19237 non-null  object
#  9   Mileage           19237 non-null  int64
#  10  Cylinders         19237 non-null  float64
#  11  Gear box type     19237 non-null  object
#  12  Drive wheels      19237 non-null  object
#  13  Wheel             19237 non-null  object
#  14  Color             19237 non-null  object
#  15  Airbags           19237 non-null  int64
# dtypes: float64(1), int64(5), object(10)
# memory usage: 2.3+ MB

# %%
data.head()
# Out:
#    Price  Levy Manufacturer    Model  Prod. year   Category Leather interior  \
# 0  13328  1399        LEXUS   RX 450        2010       Jeep              Yes
# 1  16621  1018    CHEVROLET  Equinox        2011       Jeep               No
# 2   8467   906        HONDA      FIT        2006  Hatchback               No
# 3   3607   862         FORD   Escape        2011       Jeep              Yes
# 4  11726   446        HONDA      FIT        2014  Hatchback              Yes
#
#   Fuel type Engine volume  Mileage  Cylinders Gear box type Drive wheels  \
# 0    Hybrid           3.5   186005        6.0     Automatic          4x4
# 1    Petrol             3   192000        6.0     Tiptronic          4x4
# 2    Petrol           1.3   200000        4.0      Variator        Front
# 3    Hybrid           2.5   168966        4.0     Automatic          4x4
# 4    Petrol           1.3    91901        4.0     Automatic        Front
#
#               Wheel   Color  Airbags
# 0        Left wheel  Silver       12
# 1        Left wheel   Black        8
# 2  Right-hand drive   Black        2
# 3        Left wheel   White        0
# 4        Left wheel  Silver        4

# %%
data["Engine volume"] = data["Engine volume"].str.replace("Turbo", "")
data["Engine volume"] = pd.to_numeric(data["Engine volume"])

# %%
columns_to_plot = ['Price', 'Mileage', 'Engine volume']

plt.figure(figsize=(15, 5))
for i, column in enumerate(columns_to_plot):
    plt.subplot(1, len(columns_to_plot), i + 1)
    sns.boxplot(y=data[column])
    plt.title(f'Boxplot of {column}')
    plt.ylabel(column)
plt.tight_layout()
plt.show()

# %%
data.Price.skew()
# Out:
# np.float64(136.47042654268714)

# %%
data.duplicated().sum()
# Out:
# np.int64(3512)

# %%
data.drop_duplicates(inplace=True)

# %%
data.Price.skew()
# Out:
# np.float64(123.6340713570889)

# %%
data["Price_log"] = np.log1p(data["Price"])
print(data["Price_log"].skew())
# Out:
# -1.7938697666327585

# %%
sns.boxplot(y=data["Price_log"])
# Out:
# <Axes: ylabel='Price_log'>

# %% [markdown]
# Outlier for Price_log

# %%
Q1 = data["Price_log"].quantile(0.25)
Q3 = data["Price_log"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_clean = data[(data["Price_log"] >= lower_bound) & (data["Price_log"] <= upper_bound)]

# %%
data.shape , df_clean.shape
# Out:
# ((15725, 17), (14125, 17))

# %%
sns.boxplot(y=df_clean["Price_log"])
# Out:
# <Axes: ylabel='Price_log'>

# %%
df_clean["Price_log"].hist()
# Out:
# <Axes: >

# %%
sns.boxplot(y=df_clean["Mileage"])
# Out:
# <Axes: ylabel='Mileage'>

# %%
df_clean["Mileage"].skew()
# Out:
# np.float64(35.59856847357023)

# %%
df_clean["Mileage_log"] = np.log1p(df_clean["Mileage"])
# Out:
# /tmp/ipython-input-625302387.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["Mileage_log"] = np.log1p(df_clean["Mileage"])

# %%
df_clean["Mileage_log"].skew()
# Out:
# np.float64(-3.6879460889107385)

# %%
sns.boxplot(y=df_clean["Mileage_log"])
# Out:
# <Axes: ylabel='Mileage_log'>

# %%
df_clean.shape
# Out:
# (14125, 18)

# %%
Q1 = df_clean["Price_log"].quantile(0.25)
Q3 = df_clean["Price_log"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_clean = df_clean[(df_clean["Price_log"] >= lower_bound) & (df_clean["Price_log"] <= upper_bound)]

# %%
df_clean.shape
# Out:
# (13787, 18)

# %%
sns.boxplot(y=df_clean["Mileage_log"])
# Out:
# <Axes: ylabel='Mileage_log'>

# %%
df_clean.Mileage_log.skew()
# Out:
# np.float64(-3.727233431941192)

# %%
sns.boxplot(y=df_clean["Engine volume"])
# Out:
# <Axes: ylabel='Engine volume'>

# %%
df_clean["Engine volume"].skew()
# Out:
# np.float64(2.483880146556732)

# %%
df_clean["Volume_log"] = np.log1p(df_clean["Engine volume"])

# %%
df_clean["Volume_log"].skew()
# Out:
# np.float64(0.8088368863708488)

# %%
sns.boxplot(y=df_clean["Volume_log"])
# Out:
# <Axes: ylabel='Volume_log'>

# %%
df_clean.shape
# Out:
# (13787, 19)

# %%
Q1 = df_clean["Volume_log"].quantile(0.25)
Q3 = df_clean["Volume_log"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_clean = df_clean[(df_clean["Volume_log"] >= lower_bound) & (df_clean["Volume_log"] <= upper_bound)]

# %%
df_clean.shape
# Out:
# (13419, 19)

# %%
sns.boxplot(y=df_clean["Volume_log"])
# Out:
# <Axes: ylabel='Volume_log'>

# %%
df_clean.head()
# Out:
#    Price  Levy Manufacturer    Model  Prod. year   Category Leather interior  \
# 0  13328  1399        LEXUS   RX 450        2010       Jeep              Yes
# 1  16621  1018    CHEVROLET  Equinox        2011       Jeep               No
# 2   8467   906        HONDA      FIT        2006  Hatchback               No
# 3   3607   862         FORD   Escape        2011       Jeep              Yes
# 4  11726   446        HONDA      FIT        2014  Hatchback              Yes
#
#   Fuel type  Engine volume  Mileage  Cylinders Gear box type Drive wheels  \
# 0    Hybrid            3.5   186005        6.0     Automatic          4x4
# 1    Petrol            3.0   192000        6.0     Tiptronic          4x4
# 2    Petrol            1.3   200000        4.0      Variator        Front
# 3    Hybrid            2.5   168966        4.0     Automatic          4x4
# 4    Petrol            1.3    91901        4.0     Automatic        Front
#
#               Wheel   Color  Airbags  Price_log  Mileage_log  Volume_log
# 0        Left wheel  Silver       12   9.497697    12.133534    1.504077
# 1        Left wheel   Black        8   9.718482    12.165256    1.386294
# 2  Right-hand drive   Black        2   9.044050    12.206078    0.832909
# 3        Left wheel   White        0   8.190909    12.037459    1.252763
# 4        Left wheel  Silver        4   9.369649    11.428478    0.832909

# %%
data = df_clean.drop(columns=["Model","Price","Mileage","Engine volume"])

# %%
data.head()
# Out:
#    Levy Manufacturer  Prod. year   Category Leather interior Fuel type  \
# 0  1399        LEXUS        2010       Jeep              Yes    Hybrid
# 1  1018    CHEVROLET        2011       Jeep               No    Petrol
# 2   906        HONDA        2006  Hatchback               No    Petrol
# 3   862         FORD        2011       Jeep              Yes    Hybrid
# 4   446        HONDA        2014  Hatchback              Yes    Petrol
#
#    Cylinders Gear box type Drive wheels             Wheel   Color  Airbags  \
# 0        6.0     Automatic          4x4        Left wheel  Silver       12
# 1        6.0     Tiptronic          4x4        Left wheel   Black        8
# 2        4.0      Variator        Front  Right-hand drive   Black        2
# 3        4.0     Automatic          4x4        Left wheel   White        0
# 4        4.0     Automatic        Front        Left wheel  Silver        4
#
#    Price_log  Mileage_log  Volume_log
# 0   9.497697    12.133534    1.504077
# 1   9.718482    12.165256    1.386294
# 2   9.044050    12.206078    0.832909
# 3   8.190909    12.037459    1.252763
# 4   9.369649    11.428478    0.832909

# %%
plt.figure(figsize=(6, 15))
plt.grid()
sns.barplot(data.Manufacturer.value_counts(),orient="y")
# Out:
# <Axes: xlabel='count', ylabel='Manufacturer'>

# %%
rare = data.Manufacturer.value_counts()

# %%
Others =  list(dict(rare[rare < 50]).keys())
data.Manufacturer = data.Manufacturer.apply(lambda x: "Others" if x in Others else x)

# %%
data.Manufacturer.value_counts()
# Out:
# Manufacturer
# HYUNDAI          2845
# TOYOTA           2386
# MERCEDES-BENZ    1123
# CHEVROLET         863
# FORD              816
# BMW               778
# HONDA             749
# NISSAN            502
# VOLKSWAGEN        486
# SSANGYONG         414
# Others            395
# OPEL              383
# KIA               367
# MITSUBISHI        264
# LEXUS             229
# SUBARU            196
# AUDI              152
# MAZDA             119
# JEEP              114
# FIAT               64
# SUZUKI             63
# DAEWOO             61
# DODGE              50
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 8))
plt.grid()
sns.barplot(data.Manufacturer.value_counts(),orient="y")
# Out:
# <Axes: xlabel='count', ylabel='Manufacturer'>

# %%
data.head(3)
# Out:
#    Levy Manufacturer  Prod. year   Category Leather interior Fuel type  \
# 0  1399        LEXUS        2010       Jeep              Yes    Hybrid
# 1  1018    CHEVROLET        2011       Jeep               No    Petrol
# 2   906        HONDA        2006  Hatchback               No    Petrol
#
#    Cylinders Gear box type Drive wheels             Wheel   Color  Airbags  \
# 0        6.0     Automatic          4x4        Left wheel  Silver       12
# 1        6.0     Tiptronic          4x4        Left wheel   Black        8
# 2        4.0      Variator        Front  Right-hand drive   Black        2
#
#    Price_log  Mileage_log  Volume_log
# 0   9.497697    12.133534    1.504077
# 1   9.718482    12.165256    1.386294
# 2   9.044050    12.206078    0.832909

# %%
data["Prod. year"].value_counts()
# Out:
# Prod. year
# 2012    1430
# 2014    1340
# 2013    1335
# 2016    1063
# 2015    1050
# 2011    1011
# 2010     932
# 2017     632
# 2008     471
# 2009     429
# 2007     402
# 2018     334
# 2005     328
# 2004     305
# 2003     301
# 2000     259
# 2006     258
# 2002     254
# 2001     230
# 1999     191
# 1998     187
# 2019     162
# 1997     142
# 1996      98
# 1995      94
# 1994      37
# 2020      37
# 1992      27
# 1993      20
# 1990      12
# 1991      10
# 1988       8
# 1986       5
# 1989       5
# 1987       5
# 1985       3
# 1953       3
# 1977       2
# 1964       2
# 1984       1
# 1957       1
# 1980       1
# 1982       1
# 1981       1
# Name: count, dtype: int64

# %%
scaler = StandardScaler()
data["Levy"] = scaler.fit_transform(data[["Levy"]])
data["Prod. year"] = scaler.fit_transform(data[["Prod. year"]])
data["Cylinders"] = scaler.fit_transform(data[["Cylinders"]])
data["Airbags"] = scaler.fit_transform(data[["Airbags"]])
data["Volume_log"] = scaler.fit_transform(data[["Volume_log"]])
data["Mileage_log"] = scaler.fit_transform(data[["Mileage_log"]])
data["Price_log"] = scaler.fit_transform(data[["Price_log"]])

# %%
data.head()
# Out:
#        Levy Manufacturer  Prod. year   Category Leather interior Fuel type  \
# 0  1.837600        LEXUS   -0.076539       Jeep              Yes    Hybrid
# 1  0.524311    CHEVROLET    0.094555       Jeep               No    Petrol
# 2  0.138252        HONDA   -0.760914  Hatchback               No    Petrol
# 3 -0.013414         FORD    0.094555       Jeep              Yes    Hybrid
# 4 -1.447346        HONDA    0.607836  Hatchback              Yes    Petrol
#
#    Cylinders Gear box type Drive wheels             Wheel   Color   Airbags  \
# 0   1.738319     Automatic          4x4        Left wheel  Silver  1.533405
# 1   1.738319     Tiptronic          4x4        Left wheel   Black  0.483383
# 2  -0.379769      Variator        Front  Right-hand drive   Black -1.091651
# 3  -0.379769     Automatic          4x4        Left wheel   White -1.616662
# 4  -0.379769     Automatic        Front        Left wheel  Silver -0.566640
#
#    Price_log  Mileage_log  Volume_log
# 0  -0.200984     0.422354    2.070815
# 1   0.106457     0.436160    1.439571
# 2  -0.832683     0.453926   -1.526232
# 3  -2.020672     0.380540    0.723925
# 4  -0.379290     0.115500   -1.526232

# %%
data.columns
# Out:
# Index(['Levy', 'Manufacturer', 'Prod. year', 'Category', 'Leather interior',
#        'Fuel type', 'Cylinders', 'Gear box type', 'Drive wheels', 'Wheel',
#        'Color', 'Airbags', 'Price_log', 'Mileage_log', 'Volume_log'],
#       dtype='object')

# %%
x= data[['Levy', 'Manufacturer', 'Prod. year', 'Category', 'Leather interior',
       'Fuel type', 'Cylinders', 'Gear box type', 'Drive wheels', 'Wheel',
       'Color', 'Airbags', 'Mileage_log', 'Volume_log']]
y = data["Price_log"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
cat_cols = x.select_dtypes(include='object').columns

# %%
encoder = TargetEncoder()
X_train[cat_cols] = encoder.fit_transform(X_train[cat_cols], y_train)
X_test[cat_cols] = encoder.transform(X_test[cat_cols])

# %%
### SVR

svr = SVR(kernel="rbf",
        C=300,
        epsilon=0.5)
svr.fit(X_train, y_train)

# %%
predicted = svr.predict(X_test)

# %%
mean_squared_error(y_test,predicted)
# Out:
# 0.6237073151286451

# %%
r2_score(y_test,predicted)
# Out:
# 0.38156352203261457

# %%
## Descision tree
tree = DecisionTreeRegressor(
    max_depth=10,
    min_samples_split=5,
    random_state=42)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=10, min_samples_split=5, random_state=42)

# %%
pred = tree.predict(X_test)

# %%
mean_squared_error(y_test,pred)
# Out:
# 0.8005946365734303

# %%
r2_score(y_test,pred)
# Out:
# 0.20617104319206347

# %%
## Linear Regression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred2 = lr.predict(X_test)

# %%
mean_squared_error(y_test,pred2)
# Out:
# 0.7134026795440357

# %%
lasso = Lasso()
lasso.fit(X_train, y_train)
# Out:
# Lasso()

# %%
pred = lasso.predict(X_test)

# %%
mean_squared_error(y_test,pred)
# Out:
# 1.0085228852861712

# %%
r2_score(y_test,pred)
# Out:
# -4.168179446040199e-08

# %%
ridge = Ridge()
ridge.fit(X_train, y_train)
# Out:
# Ridge()

# %%
pred = ridge.predict(X_test)
mean_squared_error(pred,y_test)
# Out:
# 0.7134044577194415

# %%
r2_score(pred,y_test)
# Out:
# -2.1254324240750035
