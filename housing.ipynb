# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Personal\OneDrive\Desktop\housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
 df.shape
# Out:
# (20640, 10)

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df["total_bedrooms"] = df["total_bedrooms"].fillna(value = df["total_bedrooms"].median())

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df.hist(figsize = (12,8))
plt.show()

# %%
df.skew(numeric_only = True)
# Out:
# longitude            -0.297801
# latitude              0.465953
# housing_median_age    0.060331
# total_rooms           4.147343
# total_bedrooms        3.481141
# population            4.935858
# households            3.410438
# median_income         1.646657
# median_house_value    0.977763
# dtype: float64

# %%
sns.histplot(df["population"])
plt.show()

# %%
df.total_rooms.skew()
# Out:
# np.float64(4.147343450632158)

# %%
from scipy.stats import boxcox
df["updated_total_rooms"] , lambda_val = boxcox(df.total_rooms)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    updated_total_rooms
# 0            15.706729
# ...

# %%
df.updated_total_rooms.skew()
# Out:
# np.float64(0.12329365118357477)

# %%
df["updated_total_bedrooms"] , lambda_val = boxcox(df.total_bedrooms)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    updated_total_rooms  updated_total_bedrooms
# ...

# %%
df.skew(numeric_only = True)
# Out:
# longitude                -0.297801
# latitude                  0.465953
# housing_median_age        0.060331
# total_rooms               4.147343
# total_bedrooms            3.481141
# population                4.935858
# households                3.410438
# median_income             1.646657
# median_house_value        0.977763
# updated_total_rooms       0.123294
# updated_total_bedrooms    0.114940
# dtype: float64

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    updated_total_rooms  updated_total_bedrooms
# ...

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity', 'updated_total_rooms',
#        'updated_total_bedrooms'],
#       dtype='object')

# %%
df = df[['housing_median_age', 'updated_total_rooms',
       'updated_total_bedrooms', 'population', 'households', 'median_income',
       'median_house_value']]

# %%
df.head()
# Out:
#    housing_median_age  updated_total_rooms  updated_total_bedrooms  \
# 0                41.0            15.706729                8.813928
# 1                21.0            27.556485               17.047639
# 2                52.0            18.123797               10.019879
# 3                52.0            17.429178               10.727891
# 4                52.0            18.647498               11.337443
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'housing_median_age'}>,
#         <Axes: title={'center': 'updated_total_rooms'}>,
#         <Axes: title={'center': 'updated_total_bedrooms'}>],
#        [<Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>],
#        [<Axes: title={'center': 'median_house_value'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
df.head()
# Out:
#    housing_median_age  updated_total_rooms  updated_total_bedrooms  \
# 0                41.0            15.706729                8.813928
# 1                21.0            27.556485               17.047639
# 2                52.0            18.123797               10.019879
# 3                52.0            17.429178               10.727891
# 4                52.0            18.647498               11.337443
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %%
df["new_population"], lambda_val = boxcox(df.population)
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_24704\2466290254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["new_population"], lambda_val = boxcox(df.population)

# %%
df.head()
# Out:
#    housing_median_age  updated_total_rooms  updated_total_bedrooms  \
# 0                41.0            15.706729                8.813928
# 1                21.0            27.556485               17.047639
# 2                52.0            18.123797               10.019879
# 3                52.0            17.429178               10.727891
# 4                52.0            18.647498               11.337443
#
#    population  households  median_income  median_house_value  new_population
# 0       322.0       126.0         8.3252            452600.0       12.308116
# 1      2401.0      1138.0         8.3014            358500.0       22.335339
# 2       496.0       177.0         7.2574            352100.0       14.082653
# 3       558.0       219.0         5.6431            341300.0       14.598634
# 4       565.0       259.0         3.8462            342200.0       14.654091

# %%
df["new_households"] , lamba_val = boxcox(df.households)
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_24704\1780077624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["new_households"] , lamba_val = boxcox(df.households)

# %%
df.head()
# Out:
#    housing_median_age  updated_total_rooms  updated_total_bedrooms  \
# 0                41.0            15.706729                8.813928
# 1                21.0            27.556485               17.047639
# 2                52.0            18.123797               10.019879
# 3                52.0            17.429178               10.727891
# 4                52.0            18.647498               11.337443
#
#    population  households  median_income  median_house_value  new_population  \
# 0       322.0       126.0         8.3252            452600.0       12.308116
# 1      2401.0      1138.0         8.3014            358500.0       22.335339
# 2       496.0       177.0         7.2574            352100.0       14.082653
# 3       558.0       219.0         5.6431            341300.0       14.598634
# 4       565.0       259.0         3.8462            342200.0       14.654091
#
#    new_households
# 0        9.264722
# 1       18.799350
# 2       10.423373
# 3       11.199955
# ...

# %%
df["new_median_income"] , lamba_val = boxcox(df.median_income)
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_24704\15011591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["new_median_income"] , lamba_val = boxcox(df.median_income)

# %%
df.skew(numeric_only=True)
# Out:
# housing_median_age        0.060331
# updated_total_rooms       0.123294
# updated_total_bedrooms    0.114940
# population                4.935858
# households                3.410438
# median_income             1.646657
# median_house_value        0.977763
# new_population            0.113081
# new_households            0.115953
# new_median_income         0.004876
# dtype: float64

# %%
df.columns
# Out:
# Index(['housing_median_age', 'updated_total_rooms', 'updated_total_bedrooms',
#        'population', 'households', 'median_income', 'median_house_value',
#        'new_population', 'new_households', 'new_median_income'],
#       dtype='object')

# %%
df = df[['housing_median_age', 'updated_total_rooms', 'updated_total_bedrooms',
       'new_population', 'new_households',  'new_median_income', 'median_house_value'
       ]]

# %%
df.head()
# Out:
#    housing_median_age  updated_total_rooms  updated_total_bedrooms  \
# 0                41.0            15.706729                8.813928
# 1                21.0            27.556485               17.047639
# 2                52.0            18.123797               10.019879
# 3                52.0            17.429178               10.727891
# 4                52.0            18.647498               11.337443
#
#    new_population  new_households  new_median_income  median_house_value
# 0       12.308116        9.264722           2.337068            452600.0
# 1       22.335339       18.799350           2.333598            358500.0
# 2       14.082653       10.423373           2.171690            352100.0
# 3       14.598634       11.199955           1.873879            341300.0
# 4       14.654091       11.840977           1.432988            342200.0

# %%
df.skew(numeric_only=True)
# Out:
# housing_median_age        0.060331
# updated_total_rooms       0.123294
# updated_total_bedrooms    0.114940
# new_population            0.113081
# new_households            0.115953
# new_median_income         0.004876
# median_house_value        0.977763
# dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df.head()
# Out:
#    housing_median_age  updated_total_rooms  updated_total_bedrooms  \
# 0                41.0            15.706729                8.813928
# 1                21.0            27.556485               17.047639
# 2                52.0            18.123797               10.019879
# 3                52.0            17.429178               10.727891
# 4                52.0            18.647498               11.337443
#
#    new_population  new_households  new_median_income  median_house_value
# 0       12.308116        9.264722           2.337068            452600.0
# 1       22.335339       18.799350           2.333598            358500.0
# 2       14.082653       10.423373           2.171690            352100.0
# 3       14.598634       11.199955           1.873879            341300.0
# 4       14.654091       11.840977           1.432988            342200.0

# %%
df["scaled_total_rooms"] = scaler.fit_transform(df[["updated_total_rooms"]])

# %%
df["scaled_total_bedrooms"] = scaler.fit_transform(df[["updated_total_bedrooms"]])

# %%
df["scaled_population"] = scaler.fit_transform(df[["new_population"]])

# %%
df["scaled_households"] = scaler.fit_transform(df[["new_households"]])

# %%
df["scaled_median_income"] = scaler.fit_transform(df[["new_median_income"]])

# %%
df.head()
# Out:
#    housing_median_age  updated_total_rooms  updated_total_bedrooms  \
# 0                41.0            15.706729                8.813928
# 1                21.0            27.556485               17.047639
# 2                52.0            18.123797               10.019879
# 3                52.0            17.429178               10.727891
# 4                52.0            18.647498               11.337443
#
#    new_population  new_households  new_median_income  median_house_value  \
# 0       12.308116        9.264722           2.337068            452600.0
# 1       22.335339       18.799350           2.333598            358500.0
# 2       14.082653       10.423373           2.171690            352100.0
# 3       14.598634       11.199955           1.873879            341300.0
# 4       14.654091       11.840977           1.432988            342200.0
#
#    scaled_total_rooms  scaled_total_bedrooms  scaled_population  \
# ...

# %%
df.columns
# Out:
# Index(['housing_median_age', 'updated_total_rooms', 'updated_total_bedrooms',
#        'new_population', 'new_households', 'new_median_income',
#        'median_house_value', 'scaled_total_rooms', 'scaled_total_bedrooms',
#        'scaled_population', 'scaled_households', 'scaled_median_income'],
#       dtype='object')

# %%
df = df[['housing_median_age','scaled_total_rooms', 'scaled_total_bedrooms',
       'scaled_population', 'scaled_households', 'scaled_median_income',
       'median_house_value']]

# %%
df.head()
# Out:
#    housing_median_age  scaled_total_rooms  scaled_total_bedrooms  \
# 0                41.0            0.360051               0.320547
# 1                21.0            0.645290               0.619993
# 2                52.0            0.418233               0.364406
# 3                52.0            0.401513               0.390155
# 4                52.0            0.430839               0.412323
#
#    scaled_population  scaled_households  scaled_median_income  \
# 0           0.247186           0.304618              0.804069
# 1           0.471409           0.618111              0.803142
# 2           0.286867           0.342714              0.759877
# 3           0.298405           0.368247              0.680296
# 4           0.299645           0.389324              0.562482
#
#    median_house_value
# 0            452600.0
# 1            358500.0
# 2            352100.0
# 3            341300.0
# 4            342200.0

# %%
x = df[['housing_median_age','scaled_total_rooms', 'scaled_total_bedrooms', 'scaled_population','scaled_households','scaled_median_income']]
y = df['median_house_value']

# %%
x.head()
# Out:
#    housing_median_age  scaled_total_rooms  scaled_total_bedrooms  \
# 0                41.0            0.360051               0.320547
# 1                21.0            0.645290               0.619993
# 2                52.0            0.418233               0.364406
# 3                52.0            0.401513               0.390155
# 4                52.0            0.430839               0.412323
#
#    scaled_population  scaled_households  scaled_median_income
# 0           0.247186           0.304618              0.804069
# 1           0.471409           0.618111              0.803142
# 2           0.286867           0.342714              0.759877
# 3           0.298405           0.368247              0.680296
# 4           0.299645           0.389324              0.562482

# %%
x.shape , y.shape
# Out:
# ((20640, 6), (20640,))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
x_train.shape , x_test.shape
# Out:
# ((16512, 6), (4128, 6))

# %%
y_train.shape , y_test.shape
# Out:
# ((16512,), (4128,))

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_, model.coef_
# Out:
# (np.float64(-206205.33379917877),
#  array([   1805.13306083, -846573.40286904,  829658.1572122 ,
#         -703400.97689567,  566046.36227306,  696450.58889095]))

# %%
pred=model.predict(x_test)
pred
# Out:
# array([ 61842.42915051, 108461.62517853, 243987.14942379, ...,
#        358329.38370948, 168687.78824517, 189615.67947065], shape=(4128,))

# %%
mean_squared_error(y_test, pred)*100
# Out:
# 640058020400.2441

# %%
r2_score(y_test, pred)
# Out:
# 0.5115585813068364
