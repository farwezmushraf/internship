# %%
import pandas as pd
import numpy as np

# %%
data = pd.Series([1,2,3,4,5], index =["a","b","c","d","e"])
data
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data.name = "Numbers"

# %%
data.size
# Out:
# 5

# %%
data
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: Numbers, dtype: int64

# %%
data.shape
# Out:
# (5,)

# %%
data.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
data["a"], data["d"]
# Out:
# (np.int64(1), np.int64(4))

# %%
data.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
data.loc[["a","e","c"]], data.iloc[3]
# Out:
# (a    1
#  e    5
#  c    3
#  Name: Numbers, dtype: int64,
#  np.int64(4))

# %%
##dataframes:

# %%
dict = {
    "usn": [1,2,3,4],
    "name": ["zms", "fwz", "arsh", "naz"],
    "age" : [20,21,23,21]
}
dict
# Out:
# {'usn': [1, 2, 3, 4],
#  'name': ['zms', 'fwz', 'arsh', 'naz'],
#  'age': [20, 21, 23, 21]}

# %%
df = pd.DataFrame(dict)
df
# Out:
#    usn  name  age
# 0    1   zms   20
# 1    2   fwz   21
# 2    3  arsh   23
# 3    4   naz   21

# %%
data = pd.read_csv(r"C:\Users\Personal\OneDrive\Desktop\sample.csv")
data.head(10)
# Out:
#    Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 0           0    101    Ram         IT   25   50000           2  2021-01-15
# 1           1    102  Shyam         HR   30   45000           5  2019-03-10
# 2           2    103  Geeta    Finance   28   60000           4  2020-07-22
# 3           3    104  Anita         IT   35   75000          10  2015-09-30
# 4           4    105  Kiran         HR   32   52000           7  2018-06-12
# 5           5    106   John    Finance   29   58000           3  2021-11-05
# 6           6    107  Meena         IT   41   82000          15  2010-04-18
# 7           7    108  David         HR   26   48000           2  2022-02-14
# 8           8    109   Sara    Finance   38   61000          12  2013-12-01
# 9           9    110  Arjun         IT   27   54000           4  2020-08-19
#
#         City  PerformanceScore
# 0  Bangalore               4.5
# 1     Mumbai               3.8
# 2      Delhi               4.2
# ...

# %%
data.tail(6)
# Out:
#     Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 14          14    115  Vijay    Finance   36   62000          11  2014-01-10
# 15          15    116   Neha         IT   40   88000          14  2011-10-21
# 16          16    117   Amit         HR   34   53000           8  2016-04-05
# 17          17    118  Pooja    Finance   30   57000           6  2018-12-12
# 18          18    119  Rahul         IT   28   56000           4  2020-02-28
# 19          19    120  Divya         HR   37   49500           9  2015-06-30
#
#          City  PerformanceScore
# 14      Delhi               4.2
# 15  Bangalore               4.7
# 16     Mumbai               4.0
# 17      Delhi               4.1
# 18  Bangalore               3.9
# 19     Mumbai               4.3

# %%
data.describe()
# Out:
#        Unnamed: 0      EmpID        Age        Salary  Experience  \
# count    20.00000   20.00000  20.000000     20.000000   20.000000
# mean      9.50000  110.50000  32.700000  59875.000000    7.400000
# std       5.91608    5.91608   5.449288  13388.796377    4.615762
# min       0.00000  101.00000  25.000000  45000.000000    2.000000
# 25%       4.75000  105.75000  28.750000  50750.000000    4.000000
# 50%       9.50000  110.50000  31.500000  56500.000000    6.000000
# 75%      14.25000  115.25000  36.250000  61250.000000   10.250000
# max      19.00000  120.00000  45.000000  90000.000000   18.000000
#
#        PerformanceScore
# count         20.000000
# mean           4.190000
# std            0.415363
# min            3.500000
# 25%            3.900000
# 50%            4.150000
# 75%            4.425000
# max            4.900000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20 non-null     int64
#  1   EmpID             20 non-null     int64
#  2   Name              20 non-null     object
#  3   Department        20 non-null     object
#  4   Age               20 non-null     int64
#  5   Salary            20 non-null     int64
#  6   Experience        20 non-null     int64
#  7   JoiningDate       20 non-null     object
#  8   City              20 non-null     object
#  9   PerformanceScore  20 non-null     float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 1.7+ KB

# %%
data.shape
# Out:
# (20, 10)

# %%
data.sample()
# Out:
#     Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 19          19    120  Divya         HR   37   49500           9  2015-06-30
#
#       City  PerformanceScore
# 19  Mumbai               4.3

# %%
data[["Name", "Age", "City"]]
# Out:
#      Name  Age       City
# 0     Ram   25  Bangalore
# 1   Shyam   30     Mumbai
# 2   Geeta   28      Delhi
# 3   Anita   35  Bangalore
# 4   Kiran   32     Mumbai
# 5    John   29      Delhi
# 6   Meena   41  Bangalore
# 7   David   26     Mumbai
# 8    Sara   38      Delhi
# 9   Arjun   27  Bangalore
# 10   Ravi   33     Mumbai
# 11  Priya   31      Delhi
# 12  Kunal   45  Bangalore
# 13  Sneha   29     Mumbai
# 14  Vijay   36      Delhi
# 15   Neha   40  Bangalore
# 16   Amit   34     Mumbai
# 17  Pooja   30      Delhi
# 18  Rahul   28  Bangalore
# 19  Divya   37     Mumbai

# %%
test2 = pd.read_csv(r"C:\Users\Personal\OneDrive\Desktop\test2.csv")
test2
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
test2.isnull()
# Out:
#    Unnamed: 0   Name    Age  Department  Salary
# 0       False  False  False       False   False
# 1       False  False  False       False   False
# 2       False  False  False       False   False
# 3       False  False   True       False   False
# 4       False  False  False       False    True
# 5       False  False  False       False   False

# %%
test2.iloc[1:4,1:4]
# Out:
#       Name   Age Department
# 1      Bob  30.0         IT
# 2  Charlie  35.0    Finance
# 3    David   NaN         IT

# %%
test2.rename(columns= {"Name":"N", "Age":"A", "Department":"Dept", "Salary":"Sal"})
test2
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
test2.drop("Unnamed: 0", axis=1,inplace=True)
test2
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
test2
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
test2["Updated_Salary"]=test2["Salary"]+ 5000

# %%
test2
# Out:
#       Name   Age Department   Salary  Updated_Salary
# 0    Alice  25.0         HR  50000.0         55000.0
# 1      Bob  30.0         IT  60000.0         65000.0
# 2  Charlie  35.0    Finance  70000.0         75000.0
# 3    David   NaN         IT  62000.0         67000.0
# 4      Eve  29.0         HR      NaN             NaN
# 5    Alice  25.0         HR  50000.0         55000.0

# %%
test2["Updated_Salary2"]=test2["Salary"].map(lambda x:x+10000)

# %%
test2
# Out:
#       Name   Age Department   Salary  Updated_Salary  Updated_Salary2
# 0    Alice  25.0         HR  50000.0         55000.0          60000.0
# 1      Bob  30.0         IT  60000.0         65000.0          70000.0
# 2  Charlie  35.0    Finance  70000.0         75000.0          80000.0
# 3    David   NaN         IT  62000.0         67000.0          72000.0
# 4      Eve  29.0         HR      NaN             NaN              NaN
# 5    Alice  25.0         HR  50000.0         55000.0          60000.0

# %%
test2["branch"]= ["ab","bc","cd","ef","gf","yt"]

# %%
test2
# Out:
#       Name   Age Department   Salary  Updated_Salary  Updated_Salary2 branch
# 0    Alice  25.0         HR  50000.0         55000.0          60000.0     ab
# 1      Bob  30.0         IT  60000.0         65000.0          70000.0     bc
# 2  Charlie  35.0    Finance  70000.0         75000.0          80000.0     cd
# 3    David   NaN         IT  62000.0         67000.0          72000.0     ef
# 4      Eve  29.0         HR      NaN             NaN              NaN     gf
# 5    Alice  25.0         HR  50000.0         55000.0          60000.0     yt

# %%
test2.drop("branch", axis=1, inplace=True)

# %%
test2
# Out:
#       Name  Age Department   Salary  Updated_Salary  Updated_Salary2
# 0    Alice   25         HR  50000.0         55000.0          60000.0
# 1      Bob   30         IT  60000.0         65000.0          70000.0
# 2  Charlie   35    Finance  70000.0         75000.0          80000.0
# 5    Alice   25         HR  50000.0         55000.0          60000.0

# %%
test2
# Out:
#    Unnamed: 0     Name   Age Department   Salary  new age
# 0           0    Alice  25.0         HR  50000.0     30.0
# 1           1      Bob  30.0         IT  60000.0     35.0
# 2           2  Charlie  35.0    Finance  70000.0     40.0
# 3           3    David   NaN         IT  62000.0      NaN
# 4           4      Eve  29.0         HR      NaN     34.0
# 5           5    Alice  25.0         HR  50000.0     30.0

# %%
test2.isnull()
# Out:
#     Name    Age  Department  Salary  Updated_Salary  Updated_Salary2
# 0  False  False       False   False           False            False
# 1  False  False       False   False           False            False
# 2  False  False       False   False           False            False
# 5  False  False       False   False           False            False

# %%
test2
# Out:
#       Name  Age Department   Salary  Updated_Salary  Updated_Salary2
# 0    Alice   25         HR  50000.0         55000.0          60000.0
# 1      Bob   30         IT  60000.0         65000.0          70000.0
# 2  Charlie   35    Finance  70000.0         75000.0          80000.0
# 5    Alice   25         HR  50000.0         55000.0          60000.0

# %%
test2.isnull().sum()
# Out:
# Name               0
# Age                0
# Department         0
# Salary             0
# Updated_Salary     0
# Updated_Salary2    0
# dtype: int64

# %%
test3= pd.read_csv(r"C:\Users\Personal\OneDrive\Desktop\test2.csv")
test3
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
test3.isnull().sum()
# Out:
# Unnamed: 0    0
# Name          0
# Age           1
# Department    0
# Salary        1
# dtype: int64

# %%
test3["Age"]= test3["Age"].fillna(value=test3["Age"].mean())
test3["Salary"]=test3["Salary"].fillna(value=test3["Salary"].mean())
test3
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  28.8         IT  62000.0
# 4           4      Eve  29.0         HR  58400.0
# 5           5    Alice  25.0         HR  50000.0

# %%
test3["Department"].value_counts()
# Out:
# Department
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
test3
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  28.8         IT  62000.0
# 4           4      Eve  29.0         HR  58400.0
# 5           5    Alice  25.0         HR  50000.0

# %%
test3["Level"] = test3.apply(lambda row: "High" if row["Salary"] >= 60000 else "Low", axis=1)

# %%
test3
# Out:
#    Unnamed: 0     Name   Age Department   Salary Level
# 0           0    Alice  25.0         HR  50000.0   Low
# 1           1      Bob  30.0         IT  60000.0  High
# 2           2  Charlie  35.0    Finance  70000.0  High
# 3           3    David  28.8         IT  62000.0  High
# 4           4      Eve  29.0         HR  58400.0   Low
# 5           5    Alice  25.0         HR  50000.0   Low

# %%
test3.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance    70000.0
# HR         52800.0
# IT         61000.0
# Name: Salary, dtype: float64

# %%
test3.groupby(["Level"]).size()
# Out:
# Level
# High    3
# Low     3
# dtype: int64

# %%
test3.groupby(["Age"]).size()
# Out:
# Age
# 25.0    2
# 28.8    1
# 29.0    1
# 30.0    1
# 35.0    1
# dtype: int64
